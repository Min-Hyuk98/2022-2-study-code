# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### classification loss(CE) + consistency loss(mse between student & teacher outputs)로 student model backpropagation
# ### 이 후 student weight 의 EMA를 teacher에 덮어씌움으로 teacher weight update
# ### 이 코드는 중간에 들어가는 noise는 딱히 없어보임..
# ### temporal ensemble은 1에폭마다 z 정보 갱신.. (iter별로는 z의 해당부분 loss구하는데 사용 & outputs에 하나씩 쌓음)
# ### mean teacher는 매 iter마다 teacher의 weight 파라미터 갱신 -> 더 빠른 학습 가능

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
root = '~/datasets/MNIST'

train_dataset = datasets.MNIST(
        root=root,
        train=True,
        transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                           ]),
        download=True)

# load test data
test_dataset = datasets.MNIST(
    root=root,
    train=False,
    transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                       ]),
    download=True)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                               batch_size=64,
                                               num_workers=2,
                                               shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                              batch_size=64,
                                              num_workers=2,
                                              shuffle=False)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4 * 4 * 50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4 * 4 * 50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def train(args, model, mean_teacher, device, train_loader, test_loader, optimizer, epoch):
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()

        output = model(data)

        # forward pass with mean teacher
        # torch.no_grad() prevents gradients from being passed into mean teacher model
        with torch.no_grad():
            mean_t_output = mean_teacher(data)

        # consistency loss (example with MSE, you can change)
        const_loss = F.mse_loss(output, mean_t_output)

        # set the consistency weight (should schedule)
        weight = 0.2
        loss = F.nll_loss(output, target) + weight*const_loss
        loss.backward()
        optimizer.step()

        ########################### CODE CHANGE HERE ######################################
        # update mean teacher, (should choose alpha somehow)
        # Use the true average until the exponential average is more correct
        alpha = 0.95
        for mean_param, param in zip(mean_teacher.parameters(), model.parameters()):
            mean_param.data.mul_(alpha).add_(1 - alpha, param.data) # teacher_param = alpha * teacher_param + (1-alpha) * student_param

        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item()))
            test(args, model, device, test_loader)
            test(args, mean_teacher, device, test_loader)


def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    model.train()

# %%
class arg():
    def __init__(self):
        self.batch_size = 64
        self.test_batch_size = 1000
        self.epochs = 10
        self.lr = 0.01
        self.momentum = 0.5
        self.no_cuda = False
        self.seed = 1
        self.log_interval = 100
        self.save_model = False

# %%
def main():
    # Training settings
    args = arg()
    

    use_cuda = not args.no_cuda and torch.cuda.is_available()

    torch.manual_seed(args.seed)

    device = torch.device("cuda" if use_cuda else "cpu")

    kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}


    model = Net().to(device)
    ########################### CODE CHANGE HERE ######################################
    # initialize mean teacher
    mean_teacher = Net().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)

    for epoch in range(1, args.epochs + 1):
        train(args, model, mean_teacher, device, train_loader, test_loader, optimizer, epoch)

    if (args.save_model):
        torch.save(model.state_dict(), "mnist_cnn.pt")


main()
# Out:
# C:\Users\82109\anaconda3\envs\pytorch_python3.7\lib\site-packages\ipykernel_launcher.py:30: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:882.)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.315416
#
# Test set: Average loss: 2.2988, Accuracy: 1165/10000 (12%)
#
#
# Test set: Average loss: 2.3035, Accuracy: 992/10000 (10%)
#
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.819462
#
# Test set: Average loss: 0.7570, Accuracy: 8546/10000 (85%)
#
#
# Test set: Average loss: 0.9504, Accuracy: 8443/10000 (84%)
#
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.398368
#
# Test set: Average loss: 0.4120, Accuracy: 9118/10000 (91%)
#
#
# Test set: Average loss: 0.4448, Accuracy: 9121/10000 (91%)
#
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.263875
#
# Test set: Average loss: 0.2878, Accuracy: 9375/10000 (94%)
#
#
# Test set: Average loss: 0.3025, Accuracy: 9364/10000 (94%)
#
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.344656
#
# Test set: Average loss: 0.2318, Accuracy: 9501/10000 (95%)
#
#
# Test set: Average loss: 0.2318, Accuracy: 9512/10000 (95%)
#
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.177535
#
# Test set: Average loss: 0.1878, Accuracy: 9572/10000 (96%)
#
#
# Test set: Average loss: 0.1909, Accuracy: 9586/10000 (96%)
#
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.107889
#
# Test set: Average loss: 0.1609, Accuracy: 9642/10000 (96%)
#
#
# Test set: Average loss: 0.1622, Accuracy: 9639/10000 (96%)
#
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.197331
#
# Test set: Average loss: 0.1429, Accuracy: 9671/10000 (97%)
#
#
# Test set: Average loss: 0.1422, Accuracy: 9687/10000 (97%)
#
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.113512
#
# Test set: Average loss: 0.1288, Accuracy: 9693/10000 (97%)
#
#
# Test set: Average loss: 0.1266, Accuracy: 9712/10000 (97%)
#
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.195535
#
# Test set: Average loss: 0.1212, Accuracy: 9715/10000 (97%)
#
#
# Test set: Average loss: 0.1156, Accuracy: 9736/10000 (97%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.174467
#
# Test set: Average loss: 0.1142, Accuracy: 9736/10000 (97%)
#
#
# Test set: Average loss: 0.1113, Accuracy: 9740/10000 (97%)
#
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.123336
#
# Test set: Average loss: 0.1018, Accuracy: 9761/10000 (98%)
#
#
# Test set: Average loss: 0.1021, Accuracy: 9773/10000 (98%)
#
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.195995
#
# Test set: Average loss: 0.0946, Accuracy: 9779/10000 (98%)
#
#
# Test set: Average loss: 0.0942, Accuracy: 9780/10000 (98%)
#
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.074575
#
# Test set: Average loss: 0.0874, Accuracy: 9793/10000 (98%)
#
#
# Test set: Average loss: 0.0876, Accuracy: 9795/10000 (98%)
#
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.083011
#
# Test set: Average loss: 0.0841, Accuracy: 9793/10000 (98%)
#
#
# Test set: Average loss: 0.0833, Accuracy: 9802/10000 (98%)
#
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.100874
#
# Test set: Average loss: 0.0788, Accuracy: 9803/10000 (98%)
#
#
# Test set: Average loss: 0.0790, Accuracy: 9803/10000 (98%)
#
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.091931
#
# Test set: Average loss: 0.0753, Accuracy: 9816/10000 (98%)
#
#
# Test set: Average loss: 0.0759, Accuracy: 9811/10000 (98%)
#
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.091037
#
# Test set: Average loss: 0.0718, Accuracy: 9830/10000 (98%)
#
#
# Test set: Average loss: 0.0723, Accuracy: 9823/10000 (98%)
#
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.048341
#
# Test set: Average loss: 0.0687, Accuracy: 9817/10000 (98%)
#
#
# Test set: Average loss: 0.0690, Accuracy: 9824/10000 (98%)
#
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.094983
#
# Test set: Average loss: 0.0679, Accuracy: 9828/10000 (98%)
#
#
# Test set: Average loss: 0.0662, Accuracy: 9832/10000 (98%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.030395
#
# Test set: Average loss: 0.0665, Accuracy: 9833/10000 (98%)
#
#
# Test set: Average loss: 0.0652, Accuracy: 9831/10000 (98%)
#
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 0.045770
#
# Test set: Average loss: 0.0628, Accuracy: 9839/10000 (98%)
#
#
# Test set: Average loss: 0.0631, Accuracy: 9837/10000 (98%)
#
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.173323
#
# Test set: Average loss: 0.0618, Accuracy: 9840/10000 (98%)
#
#
# Test set: Average loss: 0.0607, Accuracy: 9840/10000 (98%)
#
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.124391
#
# Test set: Average loss: 0.0597, Accuracy: 9847/10000 (98%)
#
#
# Test set: Average loss: 0.0582, Accuracy: 9847/10000 (98%)
#
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.040862
#
# Test set: Average loss: 0.0570, Accuracy: 9855/10000 (99%)
#
#
# Test set: Average loss: 0.0569, Accuracy: 9855/10000 (99%)
#
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.192396
#
# Test set: Average loss: 0.0577, Accuracy: 9847/10000 (98%)
#
#
# Test set: Average loss: 0.0556, Accuracy: 9856/10000 (99%)
#
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.023231
#
# Test set: Average loss: 0.0536, Accuracy: 9862/10000 (99%)
#
#
# Test set: Average loss: 0.0536, Accuracy: 9865/10000 (99%)
#
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 0.025604
#
# Test set: Average loss: 0.0525, Accuracy: 9867/10000 (99%)
#
#
# Test set: Average loss: 0.0524, Accuracy: 9864/10000 (99%)
#
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.056710
#
# Test set: Average loss: 0.0502, Accuracy: 9870/10000 (99%)
#
#
# Test set: Average loss: 0.0504, Accuracy: 9867/10000 (99%)
#
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.030633
#
# Test set: Average loss: 0.0496, Accuracy: 9866/10000 (99%)
#
#
# Test set: Average loss: 0.0495, Accuracy: 9874/10000 (99%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.060004
#
# Test set: Average loss: 0.0495, Accuracy: 9870/10000 (99%)
#
#
# Test set: Average loss: 0.0489, Accuracy: 9875/10000 (99%)
#
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 0.048092
#
# Test set: Average loss: 0.0476, Accuracy: 9874/10000 (99%)
#
#
# Test set: Average loss: 0.0479, Accuracy: 9873/10000 (99%)
#
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.021358
#
# Test set: Average loss: 0.0459, Accuracy: 9883/10000 (99%)
#
#
# Test set: Average loss: 0.0465, Accuracy: 9885/10000 (99%)
#
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.063712
#
# Test set: Average loss: 0.0456, Accuracy: 9883/10000 (99%)
#
#
# Test set: Average loss: 0.0450, Accuracy: 9885/10000 (99%)
#
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.055087
#
# Test set: Average loss: 0.0443, Accuracy: 9888/10000 (99%)
#
#
# Test set: Average loss: 0.0439, Accuracy: 9889/10000 (99%)
#
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.061388
#
# Test set: Average loss: 0.0444, Accuracy: 9879/10000 (99%)
#
#
# Test set: Average loss: 0.0431, Accuracy: 9885/10000 (99%)
#
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.054370
#
# Test set: Average loss: 0.0440, Accuracy: 9883/10000 (99%)
#
#
# Test set: Average loss: 0.0431, Accuracy: 9885/10000 (99%)
#
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 0.030366
#
# Test set: Average loss: 0.0425, Accuracy: 9887/10000 (99%)
#
#
# Test set: Average loss: 0.0424, Accuracy: 9886/10000 (99%)
#
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.021839
#
# Test set: Average loss: 0.0420, Accuracy: 9891/10000 (99%)
#
#
# Test set: Average loss: 0.0418, Accuracy: 9890/10000 (99%)
#
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.085253
#
# Test set: Average loss: 0.0417, Accuracy: 9880/10000 (99%)
#
#
# Test set: Average loss: 0.0412, Accuracy: 9887/10000 (99%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.035106
#
# Test set: Average loss: 0.0409, Accuracy: 9896/10000 (99%)
#
#
# Test set: Average loss: 0.0409, Accuracy: 9892/10000 (99%)
#
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 0.080492
#
# Test set: Average loss: 0.0417, Accuracy: 9884/10000 (99%)
#
#
# Test set: Average loss: 0.0403, Accuracy: 9891/10000 (99%)
#
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.024406
#
# Test set: Average loss: 0.0398, Accuracy: 9892/10000 (99%)
#
#
# Test set: Average loss: 0.0397, Accuracy: 9894/10000 (99%)
#
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 0.027726
#
# Test set: Average loss: 0.0395, Accuracy: 9892/10000 (99%)
#
#
# Test set: Average loss: 0.0389, Accuracy: 9894/10000 (99%)
#
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.025664
#
# Test set: Average loss: 0.0387, Accuracy: 9896/10000 (99%)
#
#
# Test set: Average loss: 0.0385, Accuracy: 9897/10000 (99%)
#
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.076292
#
# Test set: Average loss: 0.0385, Accuracy: 9896/10000 (99%)
#
#
# Test set: Average loss: 0.0386, Accuracy: 9896/10000 (99%)
#
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.014640
#
# Test set: Average loss: 0.0373, Accuracy: 9899/10000 (99%)
#
#
# Test set: Average loss: 0.0374, Accuracy: 9900/10000 (99%)
#
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 0.043298
#
# Test set: Average loss: 0.0369, Accuracy: 9902/10000 (99%)
#
#
# Test set: Average loss: 0.0368, Accuracy: 9901/10000 (99%)
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.097764
#
# Test set: Average loss: 0.0369, Accuracy: 9900/10000 (99%)
#
#
# Test set: Average loss: 0.0361, Accuracy: 9903/10000 (99%)
#
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.035693
#
# Test set: Average loss: 0.0356, Accuracy: 9902/10000 (99%)
#
#
# Test set: Average loss: 0.0355, Accuracy: 9902/10000 (99%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.029227
#
# Test set: Average loss: 0.0357, Accuracy: 9906/10000 (99%)
#
#
# Test set: Average loss: 0.0349, Accuracy: 9904/10000 (99%)
#
# Train Epoch: 6 [6400/60000 (11%)]	Loss: 0.016838
#
# Test set: Average loss: 0.0354, Accuracy: 9896/10000 (99%)
#
#
# Test set: Average loss: 0.0351, Accuracy: 9897/10000 (99%)
#
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.045411
#
# Test set: Average loss: 0.0354, Accuracy: 9901/10000 (99%)
#
#
# Test set: Average loss: 0.0351, Accuracy: 9898/10000 (99%)
#
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 0.072026
#
# Test set: Average loss: 0.0356, Accuracy: 9895/10000 (99%)
#
#
# Test set: Average loss: 0.0344, Accuracy: 9901/10000 (99%)
#
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.039905
#
# Test set: Average loss: 0.0336, Accuracy: 9902/10000 (99%)
#
#
# Test set: Average loss: 0.0338, Accuracy: 9903/10000 (99%)
#
# Train Epoch: 6 [32000/60000 (53%)]	Loss: 0.011145
#
# Test set: Average loss: 0.0334, Accuracy: 9904/10000 (99%)
#
#
# Test set: Average loss: 0.0333, Accuracy: 9904/10000 (99%)
#
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.050231
#
# Test set: Average loss: 0.0336, Accuracy: 9907/10000 (99%)
#
#
# Test set: Average loss: 0.0331, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 6 [44800/60000 (75%)]	Loss: 0.014944
#
# Test set: Average loss: 0.0331, Accuracy: 9912/10000 (99%)
#
#
# Test set: Average loss: 0.0330, Accuracy: 9907/10000 (99%)
#
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.009472
#
# Test set: Average loss: 0.0332, Accuracy: 9900/10000 (99%)
#
#
# Test set: Average loss: 0.0330, Accuracy: 9899/10000 (99%)
#
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 0.030732
#
# Test set: Average loss: 0.0329, Accuracy: 9907/10000 (99%)
#
#
# Test set: Average loss: 0.0327, Accuracy: 9908/10000 (99%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.033551
#
# Test set: Average loss: 0.0323, Accuracy: 9909/10000 (99%)
#
#
# Test set: Average loss: 0.0322, Accuracy: 9911/10000 (99%)
#
# Train Epoch: 7 [6400/60000 (11%)]	Loss: 0.063558
#
# Test set: Average loss: 0.0327, Accuracy: 9902/10000 (99%)
#
#
# Test set: Average loss: 0.0321, Accuracy: 9909/10000 (99%)
#
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.017554
#
# Test set: Average loss: 0.0317, Accuracy: 9909/10000 (99%)
#
#
# Test set: Average loss: 0.0321, Accuracy: 9907/10000 (99%)
#
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 0.055195
#
# Test set: Average loss: 0.0325, Accuracy: 9902/10000 (99%)
#
#
# Test set: Average loss: 0.0320, Accuracy: 9912/10000 (99%)
#
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.066744
#
# Test set: Average loss: 0.0324, Accuracy: 9909/10000 (99%)
#
#
# Test set: Average loss: 0.0316, Accuracy: 9909/10000 (99%)
#
# Train Epoch: 7 [32000/60000 (53%)]	Loss: 0.040228
#
# Test set: Average loss: 0.0313, Accuracy: 9905/10000 (99%)
#
#
# Test set: Average loss: 0.0311, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.017554
#
# Test set: Average loss: 0.0306, Accuracy: 9915/10000 (99%)
#
#
# Test set: Average loss: 0.0306, Accuracy: 9916/10000 (99%)
#
# Train Epoch: 7 [44800/60000 (75%)]	Loss: 0.009885
#
# Test set: Average loss: 0.0304, Accuracy: 9910/10000 (99%)
#
#
# Test set: Average loss: 0.0301, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.009383
#
# Test set: Average loss: 0.0302, Accuracy: 9914/10000 (99%)
#
#
# Test set: Average loss: 0.0300, Accuracy: 9916/10000 (99%)
#
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 0.032220
#
# Test set: Average loss: 0.0303, Accuracy: 9910/10000 (99%)
#
#
# Test set: Average loss: 0.0297, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.027275
#
# Test set: Average loss: 0.0301, Accuracy: 9910/10000 (99%)
#
#
# Test set: Average loss: 0.0297, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 8 [6400/60000 (11%)]	Loss: 0.012921
#
# Test set: Average loss: 0.0299, Accuracy: 9912/10000 (99%)
#
#
# Test set: Average loss: 0.0296, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.021301
#
# Test set: Average loss: 0.0300, Accuracy: 9913/10000 (99%)
#
#
# Test set: Average loss: 0.0297, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 0.012268
#
# Test set: Average loss: 0.0297, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0296, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.016054
#
# Test set: Average loss: 0.0293, Accuracy: 9912/10000 (99%)
#
#
# Test set: Average loss: 0.0291, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 8 [32000/60000 (53%)]	Loss: 0.034457
#
# Test set: Average loss: 0.0290, Accuracy: 9915/10000 (99%)
#
#
# Test set: Average loss: 0.0289, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.033010
#
# Test set: Average loss: 0.0293, Accuracy: 9912/10000 (99%)
#
#
# Test set: Average loss: 0.0289, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 8 [44800/60000 (75%)]	Loss: 0.014350
#
# Test set: Average loss: 0.0287, Accuracy: 9918/10000 (99%)
#
#
# Test set: Average loss: 0.0284, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.017455
#
# Test set: Average loss: 0.0287, Accuracy: 9913/10000 (99%)
#
#
# Test set: Average loss: 0.0283, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 0.005989
#
# Test set: Average loss: 0.0278, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0279, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.007114
#
# Test set: Average loss: 0.0277, Accuracy: 9921/10000 (99%)
#
#
# Test set: Average loss: 0.0277, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 9 [6400/60000 (11%)]	Loss: 0.053290
#
# Test set: Average loss: 0.0286, Accuracy: 9918/10000 (99%)
#
#
# Test set: Average loss: 0.0278, Accuracy: 9921/10000 (99%)
#
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.025010
#
# Test set: Average loss: 0.0276, Accuracy: 9919/10000 (99%)
#
#
# Test set: Average loss: 0.0275, Accuracy: 9923/10000 (99%)
#
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 0.011849
#
# Test set: Average loss: 0.0279, Accuracy: 9918/10000 (99%)
#
#
# Test set: Average loss: 0.0278, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.055431
#
# Test set: Average loss: 0.0281, Accuracy: 9916/10000 (99%)
#
#
# Test set: Average loss: 0.0274, Accuracy: 9920/10000 (99%)
#
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 0.010262
#
# Test set: Average loss: 0.0275, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0273, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.016193
#
# Test set: Average loss: 0.0269, Accuracy: 9919/10000 (99%)
#
#
# Test set: Average loss: 0.0269, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 9 [44800/60000 (75%)]	Loss: 0.040123
#
# Test set: Average loss: 0.0273, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0268, Accuracy: 9921/10000 (99%)
#
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.014718
#
# Test set: Average loss: 0.0270, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0268, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.019435
#
# Test set: Average loss: 0.0266, Accuracy: 9919/10000 (99%)
#
#
# Test set: Average loss: 0.0267, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.025097
#
# Test set: Average loss: 0.0268, Accuracy: 9919/10000 (99%)
#
#
# Test set: Average loss: 0.0267, Accuracy: 9916/10000 (99%)
#
# Train Epoch: 10 [6400/60000 (11%)]	Loss: 0.009362
#
# Test set: Average loss: 0.0266, Accuracy: 9916/10000 (99%)
#
#
# Test set: Average loss: 0.0264, Accuracy: 9923/10000 (99%)
#
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.063487
#
# Test set: Average loss: 0.0268, Accuracy: 9920/10000 (99%)
#
#
# Test set: Average loss: 0.0264, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 0.036003
#
# Test set: Average loss: 0.0266, Accuracy: 9919/10000 (99%)
#
#
# Test set: Average loss: 0.0262, Accuracy: 9922/10000 (99%)
#
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.026601
#
# Test set: Average loss: 0.0264, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0264, Accuracy: 9923/10000 (99%)
#
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 0.004048
#
# Test set: Average loss: 0.0262, Accuracy: 9921/10000 (99%)
#
#
# Test set: Average loss: 0.0261, Accuracy: 9922/10000 (99%)
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.009561
#
# Test set: Average loss: 0.0265, Accuracy: 9920/10000 (99%)
#
#
# Test set: Average loss: 0.0263, Accuracy: 9921/10000 (99%)
#
# Train Epoch: 10 [44800/60000 (75%)]	Loss: 0.026863
#
# Test set: Average loss: 0.0258, Accuracy: 9923/10000 (99%)
#
#
# Test set: Average loss: 0.0258, Accuracy: 9924/10000 (99%)
#
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.018802
#
# Test set: Average loss: 0.0254, Accuracy: 9924/10000 (99%)
#
#
# Test set: Average loss: 0.0255, Accuracy: 9924/10000 (99%)
#
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.072711
#
# Test set: Average loss: 0.0257, Accuracy: 9923/10000 (99%)
#
#
# Test set: Average loss: 0.0253, Accuracy: 9925/10000 (99%)
